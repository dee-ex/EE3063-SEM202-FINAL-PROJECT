# %%
from google.colab import drive
drive.mount('/content/drive')

root = "/content/drive/MyDrive/aicv/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv(root + "chroma_mean_feature.csv")

df
# Out:
#              0         1         2  ...        10        11  label
# 0     0.602567  0.628613  0.630453  ...  0.554043  0.547200      0
# 1     0.830845  0.837529  0.823665  ...  0.804480  0.814533      0
# 2     0.425376  0.458319  0.455490  ...  0.401697  0.407227      0
# 3     0.456393  0.453329  0.514282  ...  0.425656  0.466445      0
# 4     0.706765  0.789589  0.785787  ...  0.794263  0.728004      0
# ...        ...       ...       ...  ...       ...       ...    ...
# 4063  0.568467  0.634698  0.749025  ...  0.534030  0.515917      1
# 4064  0.565965  0.580973  0.647436  ...  0.572893  0.553220      1
# 4065  0.616556  0.676998  0.811656  ...  0.540031  0.527234      1
# 4066  0.566161  0.645865  0.747660  ...  0.529206  0.530465      1
# 4067  0.614898  0.653024  0.734855  ...  0.585025  0.566047      1
#
# [4068 rows x 13 columns]

# %%
X = df.iloc[:, :12]

minmax_scaler = MinMaxScaler()
stdard_scaler = StandardScaler()

minmax_scaler.fit(X)
stdard_scaler.fit(X)

print(minmax_scaler.data_max_)
print(minmax_scaler.data_min_)
print(stdard_scaler.mean_)

minmaxX = minmax_scaler.transform(X)
stdardX = stdard_scaler.transform(X)
# Out:
# [0.91966766 0.93062788 0.96016032 0.94102186 0.94919467 0.9280746
#  0.96528673 0.97558355 0.97554249 0.92792702 0.91013354 0.91297102]
# [0.06026641 0.05777772 0.04652851 0.04599155 0.04965884 0.05681381
#  0.05385127 0.05347334 0.05945727 0.06759546 0.06400833 0.05433762]
# [0.61326549 0.61841084 0.62628821 0.63000763 0.6346746  0.63463291
#  0.6406456  0.65318368 0.65273526 0.64104877 0.62607986 0.61598327]

# %%
minmaxdf = pd.DataFrame(minmaxX)
minmaxdf["label"] = df["label"]

minmaxdf.to_csv(root + "chroma_mean_feature_minmax.csv", index=False)

# %%
stdarddf = pd.DataFrame(stdardX)
stdarddf["label"] = df["label"]

stdarddf.to_csv(root + "chroma_mean_feature_stdard.csv", index=False)
