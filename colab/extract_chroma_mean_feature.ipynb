# %%
from google.colab import drive
drive.mount('/content/drive')

root = "/content/drive/MyDrive/aicv/"
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import os
import sys

from sklearn.neural_network import MLPClassifier

import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

# to play the audio files
from IPython.display import Audio

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import lightgbm as lgb

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
train_df = pd.read_csv(root + "train.csv")

train_df
# Out:
#                                                    path  label
# 0     /content/drive/MyDrive/aicv/train/fc802bee-ef0...      0
# 1     /content/drive/MyDrive/aicv/train/9341db3f-049...      0
# 2     /content/drive/MyDrive/aicv/train/307e7a8b-b31...      0
# 3     /content/drive/MyDrive/aicv/train/ff8c21a8-4d0...      0
# 4     /content/drive/MyDrive/aicv/train/2e9d68e1-e84...      0
# ...                                                 ...    ...
# 4063  /content/drive/MyDrive/aicv/extra_train/ba24cc...      1
# 4064  /content/drive/MyDrive/aicv/extra_train/a05f74...      1
# 4065  /content/drive/MyDrive/aicv/extra_train/edba0a...      1
# 4066  /content/drive/MyDrive/aicv/extra_train/e71761...      1
# 4067  /content/drive/MyDrive/aicv/extra_train/fa95de...      1
#
# [4068 rows x 2 columns]

# %%
def chroma_mean_feature(path):
    data, sample_rate = librosa.load(path, res_type="kaiser_fast")

    stft = np.abs(librosa.stft(data))

    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)

    return np.array(chroma)

# %%
X = []
for path in train_df['path']:
    feature = chroma_mean_feature(path)

    X.append(feature)

# %%
chroma_mean_feature_df = pd.DataFrame(X)

chroma_mean_feature_df["label"] = train_df["label"]

chroma_mean_feature_df.to_csv(root + "chroma_mean_feature.csv")
