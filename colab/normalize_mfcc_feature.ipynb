# %%
from google.colab import drive
drive.mount('/content/drive')

root = "/content/drive/MyDrive/aicv/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv(root + "mfcc_mean_feature.csv")

df
# Out:
#                0           1          2  ...         11         12  label
# 0    -469.700104   49.046539 -13.098398  ...  -2.171737  -2.124393      0
# 1    -264.004364   20.026585 -13.823114  ...  -2.052866   0.531480      0
# 2    -528.200684   33.507336  -6.445586  ...  -1.327892  -1.502330      0
# 3    -411.655151   64.029152 -38.050503  ... -12.400102  -3.227984      0
# 4    -398.290802  101.224258  -1.709527  ...  -9.790998  -2.341361      0
# ...          ...         ...        ...  ...        ...        ...    ...
# 4063 -326.665100  194.202911  39.823906  ...  -2.749095  -6.098851      1
# 4064 -360.583435  151.358185  39.784382  ...  -4.484261  -7.917335      1
# 4065 -345.741821  183.624100  29.415615  ...  -7.454377 -13.380053      1
# 4066 -360.228210  190.446991  43.780106  ...  -1.629792  -5.542675      1
# 4067 -350.179291  184.252747  42.833500  ...   0.730278  -5.602365      1
#
# [4068 rows x 14 columns]

# %%
X = df.iloc[:, :13]

minmax_scaler = MinMaxScaler()
stdard_scaler = StandardScaler()

minmax_scaler.fit(X)
stdard_scaler.fit(X)

print(minmax_scaler.data_max_)
print(minmax_scaler.data_min_)
print(stdard_scaler.mean_)

minmaxX = minmax_scaler.transform(X)
stdardX = stdard_scaler.transform(X)
# Out:
# [-136.76525879  269.1986084    53.31687927   77.09487915   41.58081818
#    49.04354095   22.02384758   30.53817368   17.21287346   27.80152512
#    17.2692852    12.44367886   15.80753803]
# [-834.59997559  -38.81786728 -115.30622101  -64.20922089  -63.62744522
#   -60.25418091  -60.86585236  -35.87390137  -44.87049103  -29.24814796
#   -27.96545029  -35.41598129  -23.0434227 ]
# [-420.27031511   58.05200705  -15.0065226     6.57780442   -6.5621591
#     0.78366707   -9.31852609   -4.87931289   -9.10875597   -2.56972174
#    -3.29291533   -6.77892187   -2.71487038]

# %%
minmaxdf = pd.DataFrame(minmaxX)
minmaxdf["label"] = df["label"]

minmaxdf.to_csv(root + "mfcc_mean_feature_minmax.csv", index=False)

# %%
stdarddf = pd.DataFrame(stdardX)
stdarddf["label"] = df["label"]

stdarddf.to_csv(root + "mfcc_mean_feature_stdard.csv", index=False)
